# %% [markdown]
# # Ejercicios para aplicar funciones, estructuras de control, colecciones, módulos y manejo de excepciones

# %% [markdown]
# Ejercicio 1: Calculadora Avanzada
# Descripción:
# Crea una función que actúe como calculadora. La función recibirá dos números y un operador (por ejemplo, '+', '-', '*', '/', '**', '//') para realizar la operación correspondiente.
#
# Utiliza estructuras de control (if/else) para seleccionar la operación a realizar.
# Usa manejo de excepciones para controlar errores como la división por cero y entradas no numéricas.
# Puedes importar el módulo math para operaciones adicionales si es necesario.
# Ejemplo de salida:
#
# Ingrese el primer número: 10 Ingrese el segundo número: 5 Ingrese el operador (+, -, *, /, **, //): / Resultado: 10 / 5 = 2.0

# %%
def calculadora():
    try:
        num1 = float(input("Ingrese el primer num: "))
        num2 = float(input("Ingrese el segundo num: "))
        operador = input("Ingrese el operador (+, -, *, /, **, //): ")

        if operador == '+':
            resultado = num1 + num2
        elif operador == '-':
            resultado = num1 - num2
        elif operador == '*':
            resultado = num1 * num2
        elif operador == '/':
            if num2 != 0:
                resultado = num1 / num2
            else:
                print("no se puede dividir")
                return
        elif operador == '**':
            resultado = num1 ** num2
        elif operador == '//':
            if num2 != 0:
                resultado = num1 // num2
            else:
                print("no se puede dividir")
                return
        else:
            print("no valido")
            return

        print(f"Resultado: {num1} {operador} {num2} = {resultado}")

    except ValueError:
        print("ingrese numeros correctos")
calculadora()
# Out:
# Ingrese el primer num: 3
# Ingrese el segundo num: 3
# Ingrese el operador (+, -, *, /, **, //): 5
# no valido

# %% [markdown]
# Este código es una calculadora básica en Python que:
#
# Pide al usuario dos números y un operador matemático (+, -, *, /, **, //).
#
# Realiza la operación elegida con los dos números.
#
# Muestra el resultado en pantalla.
#
# Evita errores si el usuario escribe mal un número o si intenta dividir por cero.
#
# Si el operador no es válido, avisa que no es válido y termina.
#
# Es útil para practicar entradas por teclado, condiciones (if) y manejo de errores con try-except.

# %% [markdown]
# Ejercicio 2: Administrador de Inventarios
# Descripción:
# Desarrolla un sistema para gestionar el inventario de productos usando un diccionario donde cada clave es el nombre del producto y su valor la cantidad en stock.
#
# Implementa funciones para agregar, actualizar y eliminar productos.
# Utiliza estructuras de control para recorrer y mostrar el inventario.
# Incluye manejo de excepciones para capturar intentos de actualizar o eliminar un producto inexistente.
# Ejemplo de salida:
# Inventario inicial: {'manzanas': 50, 'naranjas': 30, 'peras': 20} Actualizando stock de 'peras' a 25... Producto 'bananas' agregado con 40 unidades. Eliminando 'naranjas'... Inventario final: {'manzanas': 50, 'peras': 25, 'bananas': 40}texto en negrita

# %%
def mostrar_inventario(inventario):
    print("Inventario actual:")
    for producto, cantidad in inventario.items():
        print(f"- {producto}: {cantidad} unidades")
    print()

def agregar_producto(inventario, producto, cantidad):
    inventario[producto] = cantidad
    print(f"Producto '{producto}' agregado con {cantidad} unidades.")

def actualizar_producto(inventario, producto, cantidad):
    if producto in inventario:
        inventario[producto] = cantidad
        print(f"producto de '{producto}' actualizado a {cantidad} unidades.")
    else:
        print(f"El producto '{producto}' no existe en el inventario.")

def eliminar_producto(inventario, producto):
    if producto in inventario:
        del inventario[producto]
        print(f"Producto '{producto}' eliminado.")
    else:
        print(f"El producto '{producto}' no existe en el inventario.")

inventario = {'manzanas': 50, 'naranjas': 30, 'peras': 20}
mostrar_inventario(inventario)

actualizar_producto(inventario, 'peras', 2500000)
agregar_producto(inventario, 'bananas', 40)
eliminar_producto(inventario, 'naranjas')

mostrar_inventario(inventario)
# Out:
# Inventario actual:
# - manzanas: 50 unidades
# - naranjas: 30 unidades
# - peras: 20 unidades
#
# producto de 'peras' actualizado a 2500000 unidades.
# Producto 'bananas' agregado con 40 unidades.
# Producto 'naranjas' eliminado.
# Inventario actual:
# - manzanas: 50 unidades
# - peras: 2500000 unidades
# - bananas: 40 unidades

# %% [markdown]
# Este código maneja un inventario de productos con funciones para:
#
# Mostrar los productos y sus cantidades.
#
# Agregar un nuevo producto al inventario.
#
# Actualizar la cantidad de un producto existente.
#
# Eliminar un producto del inventario.
#
# Al final, se hace un ejemplo con frutas donde se:
#
# Muestra el inventario inicial.
#
# Actualizan las peras a 2,500,000 unidades.
#
# Agregan bananas.
#
# Eliminan las naranjas.
#
# Y se vuelve a mostrar el inventario actualizado.

# %% [markdown]
# Ejercicio 3: Análisis de Texto
# Descripción:
# Crea una función que reciba una cadena de texto y calcule la frecuencia de cada palabra en el mismo.
#
# Convierte el texto a minúsculas y separa las palabras usando algún método (puedes utilizar expresiones regulares con el módulo re).
# Emplea un diccionario para almacenar la palabra (clave) y su frecuencia (valor).
# Controla excepciones en caso de que el usuario no ingrese ningún texto o ingrese caracteres inesperados.
# Ejemplo de salida:
# Ingrese un texto: "Hola mundo, hola a todos en el mundo" Frecuencia de palabras: hola: 2 mundo: 2 a: 1 todos: 1 en: 1 el: 1

# %%
import re

def analizar_texto(texto):
    try:
        if not texto:
            raise ValueError("El texto no puede estar vacío.")

        texto = texto.lower()
        palabras = re.findall(r'\b\w+\b', texto)

        frecuencia = {}
        for palabra in palabras:
            if palabra in frecuencia:
                frecuencia[palabra] += 1
            else:
                frecuencia[palabra] = 1

        print("Frecuencia de palabras:")
        for palabra, cantidad in frecuencia.items():
            print(f"{palabra}: {cantidad}")

    except ValueError as e:
        print("Error:", e)
    except Exception as e:
        print("Error inesperado:", e)

texto = input("Ingrese un texto: ")
analizar_texto(texto)
# Out:
# Ingrese un texto: awo
# Frecuencia de palabras:
# awo: 1

# %% [markdown]
# Ejercicio 4: Conversor de Unidades
# Descripción:
# Desarrolla un conjunto de funciones para convertir unidades métricas. Por ejemplo:
#
# De centímetros a pulgadas.
# De kilómetros a millas.
# Utiliza estructuras de control para verificar que la entrada sea numérica, y maneja excepciones cuando el usuario ingrese datos inválidos.
# Ejemplo de salida:
# Seleccione la conversión:
#
# Centímetros a pulgadas
#
# Kilómetros a millas Opción: 1 Ingrese la cantidad en centímetros: 100 Resultado: 100 cm = 39.37 pulgadas

# %%
def cm_a_pulgadas(cm):
    return cm / 2.54

def km_a_millas(km):
    return km * 0.621371

def convertir_unidades():
    try:
        print("Seleccione la conversión:")
        print("1. Centímetros a pulgadas")
        print("2. Kilómetros a millas")

        opcion = int(input("Opción: "))

        if opcion == 1:
            cm = float(input("Ingrese la cantidad en centímetros: "))
            resultado = cm_a_pulgadas(cm)
            print(f"{cm} cm = {resultado:.2f} pulgadas")

        elif opcion == 2:
            km = float(input("Ingrese la cantidad en kilómetros: "))
            resultado = km_a_millas(km)
            print(f"{km} km = {resultado:.2f} millas")

        else:
            print("Opción no válida.")

    except ValueError:
        print("Error")

convertir_unidades()
def cm_a_pulgadas(cm):
    return cm / 2.54

def km_a_millas(km):
    return km * 0.621371

def convertir_unidades():
    try:
        print("Seleccione la conversión:")
        print("1. Centímetros a pulgadas")
        print("2. Kilómetros a millas")

        opcion = int(input("Opción: "))

        if opcion == 1:
            cm = float(input("Ingrese la cantidad en centímetros: "))
            resultado = cm_a_pulgadas(cm)
            print(f"{cm} cm = {resultado:.2f} pulgadas")

        elif opcion == 2:
            km = float(input("Ingrese la cantidad en kilómetros: "))
            resultado = km_a_millas(km)
            print(f"{km} km = {resultado:.2f} millas")

        else:
            print("error")

    except ValueError:
        print("opcion invalida")

convertir_unidades()
# Out:
# Seleccione la conversión:
# 1. Centímetros a pulgadas
# 2. Kilómetros a millas
# Opción: centimetros a pulgadas
# Error
# Seleccione la conversión:
# 1. Centímetros a pulgadas
# 2. Kilómetros a millas
# Opción: 12
# error

# %% [markdown]
# Este código es un convertidor de unidades que:
#
# Pide al usuario elegir entre:
#
# Convertir centímetros a pulgadas.
#
# Convertir kilómetros a millas.
#
# Calcula la conversión según la opción elegida.
#
# Muestra el resultado con dos decimales.
#
# Maneja errores si el usuario escribe algo incorrecto.
#
# 🧠 Básicamente, convierte medidas de largo y distancia de una unidad a otra.

# %% [markdown]
# Ejercicio 5: Juego "Adivina el Número"
# Descripción:
# Implementa un juego en el que la computadora selecciona aleatoriamente un número en un rango (por ejemplo, 1 a 50) y el usuario debe adivinarlo.
#
# Emplea el módulo random para generar el número secreto.
# Utiliza un bucle que permita múltiples intentos, con retroalimentación indicando si el número ingresado es mayor o menor que el secreto.
# Gestiona excepciones para capturar entradas no numéricas.
# Ejemplo de salida:
# ¡Bienvenido al juego "Adivina el Número"! Estoy pensando en un número entre 1 y 50. Intento 1 - Ingresa tu número: 25 El número secreto es mayor. Intento 2 - Ingresa tu número: 35 El número secreto es menor. Intento 3 - Ingresa tu número: 30 ¡Felicidades! Has adivinado el número secreto: 30

# %%
import random

def adivina_el_numero():
    numero_secreto = random.randint(1, 50)
    intento = 1

    print("Bienvenido al juego tienes que adivinar el numero")
    print("Estoy pensando en un número entre 1 y 50")

    while True:
        try:
            numero_usuario = int(input(f"Intento {intento} - Ingresa tu número: "))

            if numero_usuario < numero_secreto:
                print("El número secreto es mayor")
            elif numero_usuario > numero_secreto:
                print("El número secreto es menor")
            else:
                print(f"¡Felicidades! : {numero_secreto}")
                break

            intento += 1

        except ValueError:
            print("¡Error!")

adivina_el_numero()
# Out:
# Bienvenido al juego tienes que adivinar el numero
# Estoy pensando en un número entre 1 y 50
# Intento 1 - Ingresa tu número: 45
# El número secreto es menor
# Intento 2 - Ingresa tu número: 46
# El número secreto es menor
# Intento 3 - Ingresa tu número: 87
# El número secreto es menor
# Intento 4 - Ingresa tu número: 89
# El número secreto es menor
# Intento 5 - Ingresa tu número: 98
# El número secreto es menor
# Intento 6 - Ingresa tu número: 34
# El número secreto es mayor
# Intento 7 - Ingresa tu número: 24
# El número secreto es mayor
# Intento 8 - Ingresa tu número: 30
# El número secreto es mayor
# Intento 9 - Ingresa tu número: 40
# El número secreto es menor
# Intento 10 - Ingresa tu número: 35
# El número secreto es mayor
# Intento 11 - Ingresa tu número: 38
# El número secreto es mayor
# Intento 12 - Ingresa tu número: 39
# ¡Felicidades! : 39

# %% [markdown]
# Este código es un juego para adivinar un número entre 1 y 50:
#
# Elige un número secreto al azar.
#
# El usuario intenta adivinarlo.
#
# El programa dice si el número es mayor o menor que el secreto.
#
# Sigue hasta que el usuario acierte.
#
# Maneja errores si el usuario no escribe un número.

# %% [markdown]
# Ejercicio 6: Calculadora de Factorial
# Descripción:
# Crea una función que calcule el factorial de un número entero ingresado por el usuario.
#
# La función debe utilizar estructuras de control para iterar (o una solución recursiva) y calcular el factorial.
# Implementa manejo de excepciones para asegurarte de que el número ingresado es entero y no negativo.
# Ejemplo de salida:
# Ingrese un número entero para calcular su factorial: 5 El factorial de 5 es 120

# %%
def calcular_factorial():
    try:
        numero = int(input("Ingrese un número entero para calcular su factorial: "))

        if numero < 0:
            print("El número no puede ser negativo.")
            return

        factorial = 1
        for i in range(1, numero + 1):
            factorial *= i

        print(f"El factorial de {numero} es {factorial}")

    except ValueError:
        print("Debes ingresar un número entero válido")

calcular_factorial()
# Out:
# Ingrese un número entero para calcular su factorial: 1315
# El factorial de 1315 es ...

# %% [markdown]
# Este código calcula el factorial de un número entero que el usuario ingresa:
#
# Pide un número entero.
#
# Si es negativo, muestra un mensaje de error.
#
# Si es válido, calcula el factorial (multiplica todos los números desde 1 hasta ese número).
#
# Muestra el resultado.
#
# Si el usuario escribe algo incorrecto, muestra un mensaje de error.
#
# 🧮 Es una forma simple de obtener el factorial de un número paso a paso.

# %% [markdown]
# Ejercicio 7: Manejo de Fechas y Horas
# Descripción:
# Desarrolla una función que reciba una fecha ingresada por el usuario en formato "DD/MM/AAAA" y determine cuántos días faltan para esa fecha a partir de hoy.
#
# Importa el módulo datetime para trabajar con fechas.
# Utiliza estructuras de control para validar el formato y maneja excepciones en caso de error en el ingreso de la fecha.
# Ejemplo de salida:
# Ingrese una fecha (DD/MM/AAAA): 25/12/2023 Faltan 150 días para el 25/12/2023.

# %%
from datetime import datetime

def calcular_dias_faltantes():
    try:
        fecha_str = input("Ingrese una fecha (DD/MM/AAAA): ")
        fecha_ingresada = datetime.strptime(fecha_str, "%d/%m/%Y")
        fecha_hoy = datetime.today()
        diferencia = fecha_ingresada - fecha_hoy
        dias_faltantes = diferencia.days

        if dias_faltantes < 0:
            print(f"La fecha ingresada ya pasó. Fue hace {-dias_faltantes} días.")
        else:
            print(f"Faltan {dias_faltantes} días para el {fecha_str}.")

    except ValueError:
        print("El formato de la fecha debe ser DD/MM/AAAA.")

calcular_dias_faltantes()
# Out:
# Ingrese una fecha (DD/MM/AAAA): 12/12/2012
# La fecha ingresada ya pasó. Fue hace 4513 días.

# %% [markdown]
# Este código calcula cuántos días faltan para una fecha que el usuario ingresa:
#
# Pide una fecha en formato DD/MM/AAAA.
#
# Compara esa fecha con la fecha de hoy.
#
# Si la fecha ya pasó, dice cuántos días han pasado.
#
# Si aún no llega, dice cuántos días faltan.
#
# Si el formato está mal, muestra un mensaje de error.
#
# 📅 Es útil para saber si una fecha está en el pasado o futuro, y cuántos días hay de diferencia.

# %% [markdown]
# Ejercicio 8: Registro de Estudiantes
# Descripción:
# Implementa un sistema que gestione un registro de estudiantes utilizando un diccionario, donde la clave sea el nombre y el valor la calificación.
#
# Crea funciones para agregar un estudiante, actualizar la calificación, eliminar estudiantes y listar todo el registro.
# Utiliza un bucle para mostrar un menú interactivo al usuario.
# Maneja excepciones para gestionar errores en la selección de opciones o al intentar modificar un estudiante inexistente.
# Ejemplo de salida:
# Registro de estudiantes inicial: {'Ana': 90, 'Luis': 78, 'Carlos': 85}
#
# Menú:
#
# Agregar estudiante
#
# Actualizar calificación
#
# Eliminar estudiante
#
# Listar estudiantes
#
# Salir
#
# Opción: 2 Ingrese el nombre del estudiante: Luis Ingrese la nueva calificación: 82 Estudiante actualizado: Luis - 82
#
# Registro final: {'Ana': 90, 'Luis': 82, 'Carlos': 85}

# %%
def agregar_estudiante(registro, nombre, calificacion):
    registro[nombre] = calificacion
    print(f"Estudiante agregado: {nombre} - {calificacion}")

def actualizar_calificacion(registro, nombre, calificacion):
    if nombre in registro:
        registro[nombre] = calificacion
        print(f"Estudiante actualizado: {nombre} - {calificacion}")
    else:
        print(f"Error: El estudiante {nombre} no existe.")

def eliminar_estudiante(registro, nombre):
    if nombre in registro:
        del registro[nombre]
        print(f"Estudiante {nombre} eliminado.")
    else:
        print(f"Error: El estudiante {nombre} no existe.")

def listar_estudiantes(registro):
    if registro:
        print("Registro de estudiantes:")
        for nombre, calificacion in registro.items():
            print(f"{nombre}: {calificacion}")
    else:
        print("No hay estudiantes registrados.")

def menu():
    registro = {'Ana': 90, 'Luis': 78, 'Carlos': 85}

    while True:
        print("\nMenú:")
        print("1. Agregar estudiante")
        print("2. Actualizar calificación")
        print("3. Eliminar estudiante")
        print("4. Listar estudiantes")
        print("5. Salir")

        try:
            opcion = int(input("Opción: "))

            if opcion == 1:
                nombre = input("Ingrese el nombre del estudiante: ")
                calificacion = float(input("Ingrese la calificación: "))
                agregar_estudiante(registro, nombre, calificacion)

            elif opcion == 2:
                nombre = input("Ingrese el nombre del estudiante: ")
                calificacion = float(input("Ingrese la nueva calificación: "))
                actualizar_calificacion(registro, nombre, calificacion)

            elif opcion == 3:
                nombre = input("Ingrese el nombre del estudiante a eliminar: ")
                eliminar_estudiante(registro, nombre)

            elif opcion == 4:
                listar_estudiantes(registro)

            elif opcion == 5:
                print("Saliendo del programa.")
                break

            else:
                print("Opción no válida.")

        except ValueError:
            print("Error: Debes ingresar una opción válida.")

    print(f"Registro final: {registro}")

menu()
# Out:
# Menú:
# 1. Agregar estudiante
# 2. Actualizar calificación
# 3. Eliminar estudiante
# 4. Listar estudiantes
# 5. Salir
# Opción: calificacion de estudiante
# Error: Debes ingresar una opción válida.
#
# Menú:
# 1. Agregar estudiante
# 2. Actualizar calificación
# 3. Eliminar estudiante
# 4. Listar estudiantes
# 5. Salir
# Opción: andres
# Error: Debes ingresar una opción válida.
#
# Menú:
# 1. Agregar estudiante
# 2. Actualizar calificación
# 3. Eliminar estudiante
# 4. Listar estudiantes
# 5. Salir
# Opción: andres 5  andres  8
# Error: Debes ingresar una opción válida.
#
# Menú:
# 1. Agregar estudiante
# 2. Actualizar calificación
# 3. Eliminar estudiante
# 4. Listar estudiantes
# 5. Salir

# %% [markdown]
# Este código gestiona un registro de estudiantes y sus calificaciones, con un menú interactivo para:
#
# Agregar un estudiante con su calificación.
#
# Actualizar la calificación de un estudiante existente.
#
# Eliminar un estudiante del registro.
#
# Listar todos los estudiantes y sus calificaciones.
#
# Salir del programa.
#
# El programa permite interactuar con las opciones y maneja errores si el usuario ingresa datos incorrectos. Al final, muestra el registro actualizado de estudiantes.
#
# 📚 Es un sistema sencillo para gestionar estudiantes y sus notas.

# %% [markdown]
# Ejercicio 9: Generador de Contraseñas Aleatorias
# Descripción:
# Crea una función que genere una contraseña aleatoria de una longitud especificada por el usuario.
#
# Utiliza el módulo random junto con la biblioteca string para construir la contraseña a partir de letras (mayúsculas y minúsculas), dígitos y caracteres especiales.
# Valida la entrada y maneja excepciones para asegurarte de que la longitud es un número entero positivo.
# Ejemplo de salida:
# Ingrese la longitud deseada para la contraseña: 10 Contraseña generada: A8b#K3d!Qz

# %%
import random
import string

def generar_contraseña():
    try:
        longitud = int(input("Ingrese la longitud deseada para la contraseña: "))

        if longitud <= 0:
            print("La longitud debe ser un número entero positivo.")
            return

        caracteres = string.ascii_letters + string.digits + string.punctuation
        contraseña = ''.join(random.choice(caracteres) for _ in range(longitud))

        print(f"Contraseña generada: {contraseña}")

    except ValueError:
        print("La longitud debe ser un número entero positivo.")

generar_contraseña()
# Out:
# Ingrese la longitud deseada para la contraseña: 14
# Contraseña generada: C_oYRa\JctaW+t

# %% [markdown]
# Este código genera una contraseña aleatoria con los siguientes pasos:
#
# Pide al usuario que ingrese la longitud deseada para la contraseña.
#
# Si la longitud es válida (mayor que 0), genera una contraseña utilizando letras, números y caracteres especiales.
#
# Muestra la contraseña generada.
#
# Si la longitud ingresada no es válida, muestra un mensaje de error.
#
# 🔐 Es útil para crear contraseñas seguras y aleatorias.

# %% [markdown]
# Ejercicio 10: Buscador de Archivos en un Directorio
# Descripción:
# Desarrolla una función que reciba el nombre de un directorio y una subcadena para buscar archivos cuyo nombre la contenga.
#
# Utiliza el módulo os para listar el contenido del directorio.
# Aplica estructuras de control para filtrar los archivos según la subcadena.
# Implementa manejo de excepciones para controlar errores como directorio no existente o permisos insuficientes.
# Ejemplo de salida:
# Ingrese la ruta del directorio: /ruta/al/directorio Ingrese la subcadena a buscar: reporte Archivos encontrados que contienen "reporte":
#
# reporte_enero.pdf
#
# reporte_febrero.xlsx
#
# resumen_reporte.txt

# %%
import os

def buscar_archivos():
    try:
        directorio = input("Ingrese la ruta del directorio: ")
        subcadena = input("Ingrese la subcadena a buscar: ")

        if not os.path.isdir(directorio):
            print("El directorio no existe o no es un directorio válido.")
            return

        archivos_encontrados = []
        for archivo in os.listdir(directorio):
            if os.path.isfile(os.path.join(directorio, archivo)) and subcadena in archivo:
                archivos_encontrados.append(archivo)

        if archivos_encontrados:
            print(f"Archivos encontrados que contienen \"{subcadena}\":")
            for archivo in archivos_encontrados:
                print(archivo)
        else:
            print(f"No se encontraron archivos que contengan \"{subcadena}\".")

    except PermissionError:
        print("Permisos insuficientes para acceder al directorio.")
    except Exception as e:
        print(f"Error: {e}")

buscar_archivos()

# %% [markdown]
# Este código busca archivos dentro de un directorio que contengan una subcadena específica en su nombre:
#
# Pide al usuario ingresar la ruta del directorio y la subcadena a buscar.
#
# Verifica que el directorio exista y sea válido.
#
# Recorre los archivos del directorio y guarda los que contienen la subcadena.
#
# Muestra los archivos encontrados o un mensaje si no se encuentra ninguno.
#
# Maneja errores si el directorio no existe o si hay problemas de permisos.
#
# 🔍 Es útil para buscar archivos específicos en una carpeta según su nombre.
